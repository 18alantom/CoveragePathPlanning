# %%
import numpy as np
import math
from scipy.spatial import distance
from warnings import warn
import time
from pathlib import Path

# %%
from cpp_algorithms.testers import imshow, imshow_scatter
from cpp_algorithms.testers import get_all_area_maps, get_random_coords, get_area_map
from cpp_algorithms.testers.metrics import coverage_metrics
from cpp_algorithms.testers.display_funcs import printer
from cpp_algorithms.testers import is_valid
# Out:
# /Users/alan/Desktop/stuff/SIH/nm_383_cpp/cpp_algorithms/testers/testers.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# # A - Star
# (untouched)

# %%
def backTrackingList(Memory, diameter, M, Critical_x, Critical_y):
    resultList=[]
    
    for a in Memory:
        x=a[0]
        y=a[1]
        sum1=0
        
        if(sum(map(sum, M[x:x-diameter:-1, y+diameter:y+2*diameter])) == 255*diameter*diameter and (sum(map(sum, M[x:x+diameter, y+diameter:y+2*diameter]))<255*diameter*diameter   or sum(map(sum, M[x:x+diameter, y+diameter:y+2*diameter])) == 150*diameter*diameter)):
            sum1=sum1+1
        
        if(sum(map(sum, M[x:x-diameter:-1, y+diameter:y+2*diameter])) == 255*diameter*diameter and (sum(map(sum, M[x-diameter:x-2*diameter:-1, y+diameter:y+2*diameter])) <255*diameter*diameter or sum(map(sum, M[x-diameter:x-2*diameter:-1, y+diameter:y+2*diameter])) == 150*diameter*diameter)):
            sum1=sum1+1
            
        if(sum(map(sum, M[x:x-diameter:-1, y-diameter:y])) == 255*diameter*diameter and (sum(map(sum, M[x:x+diameter, y:y-diameter:-1])) <255*diameter*diameter  or sum(map(sum, M[x:x+diameter, y:y-diameter:-1])) == 150*diameter*diameter)):
            sum1=sum1+1
            
            
        if(sum(map(sum, M[x:x-diameter:-1, y-diameter:y])) == 255*diameter*diameter and (sum(map(sum, M[x-diameter:x-2*diameter:-1, y:y-diameter:-1]))<255*diameter*diameter or sum(map(sum, M[x-diameter:x-2*diameter:-1, y:y-diameter:-1])) == 150*diameter*diameter)):
            sum1=sum1+1
            
        if(sum(map(sum, M[x+diameter:x:-1, y:y+diameter])) == 255*diameter*diameter and (sum(map(sum, M[x:x+diameter, y:y-diameter:-1])) <255*diameter*diameter or sum(map(sum, M[x:x+diameter, y:y-diameter:-1])) == 150*diameter*diameter)):
            sum1=sum1+1
            
        if(sum(map(sum, M[x+diameter:x:-1, y:y+diameter])) == 255*diameter*diameter and (sum(map(sum, M[x:x+diameter, y+diameter:y+2*diameter])) <255*diameter*diameter or sum(map(sum, M[x:x+diameter, y+diameter:y+2*diameter])) == 150*diameter*diameter)):
            sum1=sum1+1
            
        
        if sum1 >= 1:
            resultList.append(a)
            
    if (len(resultList) ==0):
        return 0, 0
    elif (len(resultList) ==1):
        for i in resultList:
            x=i[0]
            y=i[1]
            #print(x, y)
            return x, y
    else:
        minimum=[]
        for z in resultList:
            p1=(Critical_x, Critical_y)
            p2=(z[0], z[1])
            d=distance.euclidean(p1, p2)
            minimum.append(d)
            #print(minimum)
            
        min1=minimum[0]
        index=0
        
        for p in range(len(minimum)):
            if minimum[p] < min1:
                index=p

        list_of_coord=[] 
        list_of_coord=resultList[index]
        return list_of_coord[0], list_of_coord[1]

# %%
def heuristic(start, goal):
    #Use Chebyshev distance heuristic if we can move one square either
    #adjacent or diagonal
    D = 1
    D2 = 1
    dx = abs(start[0] - goal[0])
    dy = abs(start[1] - goal[1])
    return D * (dx + dy) + (D2 - 2 * D) * min(dx, dy)
    
def get_vertex_neighbours(pos, diameter, width, height):
    n = []
    #Moves allow link a chess king
    for dx, dy in [(diameter,0),(-diameter,0),(0,diameter),(0,-diameter)]:
        x2 = pos[0] + dx
        y2 = pos[1] + dy
        if x2 < 0 or x2 > width-1  or y2 < 0 or y2 > height-1:
            continue
        n.append((x2, y2))
    return n

# %%
def AStarSearch(start, end, graph, diameter, width, height):
 
    G = {} #Actual movement cost to each position from the start position
    F = {} #Estimated movement cost of start to end going via this position
 
    #Initialize starting values
    G[start] = 0 
    F[start] = heuristic(start, end)
 
    closedVertices = set()
    openVertices = set([start])
    cameFrom = {}
    
    # Adding a stop condition
    outer_iterations = 0
    max_iterations = (len(graph[0]) * len(graph) // 2)
 
    while len(openVertices) > 0:
        outer_iterations += 1

        if outer_iterations > max_iterations:
            warn("giving up on pathfinding too many iterations")
            
        #Get the vertex in the open list with the lowest F score
        current = None
        currentFscore = None
        for pos in openVertices:
            if current is None or F[pos] < currentFscore:
                currentFscore = F[pos]
                current = pos
 
        #Check if we have reached the goal
        if current == end:
            #Retrace our route backward
            path = [current]
            while current in cameFrom:
                current = cameFrom[current]
                path.append(current)
            path.reverse()
            return path  #Done!
 
        #Mark the current vertex as closed
        openVertices.remove(current)
        closedVertices.add(current)
 
        #Update scores for vertices near the current position
        for neighbour in get_vertex_neighbours(current, diameter, width, height):
            if neighbour in closedVertices: 
                continue #We have already processed this node exhaustively
            x=neighbour[0]
            y=neighbour[1]
            if graph[x][y]!=150:
                continue
            else:
                candidateG = G[current] + 1
 
            if neighbour not in openVertices:
                openVertices.add(neighbour) #Discovered a new vertex
            
            elif candidateG >= G[neighbour]:
                continue #This G score is worse than previously found
 
            #Adopt this G score
            cameFrom[neighbour] = current
            G[neighbour] = candidateG
            H = heuristic(neighbour, end)
            F[neighbour] = G[neighbour] + H
 
    raise RuntimeError("A* failed to find a solution")

# %%
def AstarPath(M, Memory, path):
    for q in path:
        x=q[0]
        y=q[1]
        Memory.append((x, y))

# %% [markdown]
# # Boustrophedon and caller

# %%
def bous_preprocess(area_map):
    """
    Returns matrix that in the form
    that is read by the main algorithm.
    """
    matrix = np.full(area_map.shape, 0, dtype=np.uint8)
    matrix[area_map == 0] = 255
    return matrix

def do_everything(matrix, start_point, break_after_bous=False):
    start_time = time.time()
    
    width, height = matrix.shape
    radius=0.5
    diameter=int(2*radius)

    x, y = start_point
    memory=[]

    Flag=True
    while True:
        critical_x, critical_y = boustrophedon(matrix, diameter, x, y, memory)
        
        if break_after_bous:
            print("break point",critical_x,critical_y)
            break
            
        x, y = backTrackingList(memory, diameter, matrix, critical_x, critical_y)
        if(x == 0 and y == 0):
            Flag=False
            break
        else:
            start = (critical_x,critical_y )
            end = (x, y)
            path = AStarSearch(start, end, matrix, diameter, width, height)
            AstarPath(matrix, memory, path)
            
    return memory

# %%
def visit(matrix, x, y, memory):
    matrix[(x,y)] = 150 # 150 == visited
    memory.append((x, y))
    return x,y

def boustrophedon(matrix, diameter, x, y, memory):
    # TODO :: Variable diameter support
    udlr = {
        "u": lambda x,y : (x-diameter,y),
        "d": lambda x,y : (x+diameter,y),
        "l": lambda x,y : (x,y-diameter),
        "r": lambda x,y : (x,y+diameter)
    }
    u = "u";d = "d";r = "r";l = "l"
    visit(matrix, x, y, memory)
    
    while True:
        dir_ = [u,d,r,l]
        while len(dir_) > 0:
            d_ = dir_.pop(0)
            x_, y_ = udlr[d_](x,y)
            if is_valid((x_,y_), matrix, [0, 150]):
                x, y = visit(matrix, x_, y_, memory)
                break
            elif d_ == l:
                return x, y

# %%
area_maps = get_all_area_maps("./test_maps/")

# %%
# area_map = area_maps[0]
area_map = np.full((100,100), 0)
# start_point = (49,0)
start_point = get_random_coords(area_map, 1)[0]
matrix = bous_preprocess(area_map)
# %time coverage_path = do_everything(matrix, start_point, break_after_bous=True)
end_point = coverage_path[-1]

printer(coverage_metrics(area_map, coverage_path))
print()

imshow(matrix, cmap="cividis")
imshow_scatter(coverage_path, alpha=0.4, color="white",s=1)
imshow_scatter([start_point],color="lightgreen")
imshow_scatter([end_point],color="red")
# Out:
# break point 99 99
# CPU times: user 60.5 ms, sys: 2.86 ms, total: 63.4 ms
# Wall time: 70.5 ms
#      points_to_visit : 10000
#      obstacle_points : 0
#       points_visited : 4598
#    coverage_path_len : 4598
#             coverage : 0.4598
#           redundancy : 0.0
#           area_shape : (100, 100)

# %%
imshow(area_maps[8])

# %%
area_map = area_maps[8]
for i in range(5):
    start_point = get_random_coords(area_map, 1)[0]
    matrix = bous_preprocess(area_map)
    # %time coverage_path = do_everything(matrix, start_point)
    end_point = coverage_path[-1]
    print(f"start: {start_point}, end: {end_point}")
    printer(coverage_metrics(area_map, coverage_path))
    print()

    imshow(matrix, cmap="Greys_r",figsize=(10,10))
    imshow_scatter(coverage_path, alpha=0.5, color="lightblue",s=4)
    imshow_scatter([start_point], color="black")
    imshow_scatter([end_point],color="red")
# Out:
# CPU times: user 216 ms, sys: 3.43 ms, total: 220 ms
# Wall time: 227 ms
# start: (28, 6), end: (31, 8)
#      points_to_visit : 772
#      obstacle_points : 252
#       points_visited : 415
#    coverage_path_len : 616
#             coverage : 0.5375647668393783
#           redundancy : 0.48433734939759043
#           area_shape : (32, 32)
#
# CPU times: user 189 ms, sys: 831 µs, total: 190 ms
# Wall time: 195 ms
# start: (26, 22), end: (17, 30)
#      points_to_visit : 772
#      obstacle_points : 252
#       points_visited : 415
#    coverage_path_len : 576
#             coverage : 0.5375647668393783
#           redundancy : 0.38795180722891565
#           area_shape : (32, 32)
#
# CPU times: user 885 ms, sys: 11.8 ms, total: 896 ms
# Wall time: 1.02 s
# start: (3, 28), end: (9, 28)
#      points_to_visit : 772
#      obstacle_points : 252
#       points_visited : 772
#    coverage_path_len : 1133
#             coverage : 1.0
#           redundancy : 0.46761658031088094
#           area_shape : (32, 32)
#
# CPU times: user 267 ms, sys: 5.11 ms, total: 272 ms
# Wall time: 306 ms
# start: (12, 0), end: (20, 0)
#      points_to_visit : 772
#      obstacle_points : 252
#       points_visited : 415
#    coverage_path_len : 643
#             coverage : 0.5375647668393783
#           redundancy : 0.5493975903614459
#           area_shape : (32, 32)
#
# CPU times: user 996 ms, sys: 12.4 ms, total: 1.01 s
# Wall time: 1.13 s
# start: (7, 30), end: (7, 20)
#      points_to_visit : 772
#      obstacle_points : 252
#       points_visited : 772
#    coverage_path_len : 1123
#             coverage : 1.0
#           redundancy : 0.4546632124352332
#           area_shape : (32, 32)

# %%
for i,path in enumerate(Path("./test_maps/").iterdir()):
    if path.suffix != ".png":
        continue
    area_map = get_area_map(path)
    # Remove conditional to run on all maps.
#     if area_map.shape[1] > 50:
#         continue
    print(f"# {i} :: ",area_map.shape, path.name)
    start_point = get_random_coords(area_map, 1)[0]
    matrix = bous_preprocess(area_map)
    # %time coverage_path = do_everything(matrix, start_point)
    end_point = coverage_path[-1]
    printer(coverage_metrics(area_map, coverage_path))
    print()

    imshow(matrix, cmap="Greys_r",figsize=(10,10))
    imshow_scatter(coverage_path, alpha=0.5, color="lightblue",s=4)
    imshow_scatter([start_point], color="black")
    imshow_scatter([end_point],color="red")
# Out:
# # 0 ::  (32, 32) corners_0.png
# CPU times: user 419 ms, sys: 5.6 ms, total: 425 ms
# Wall time: 449 ms
#      points_to_visit : 716
#      obstacle_points : 308
#       points_visited : 716
#    coverage_path_len : 949
#             coverage : 1.0
#           redundancy : 0.3254189944134078
#           area_shape : (32, 32)
#
# # 2 ::  (256, 256) comb_9.png
# CPU times: user 5min 12s, sys: 992 ms, total: 5min 13s
# Wall time: 5min 59s
#      points_to_visit : 33385
#      obstacle_points : 32151
#       points_visited : 33385
#    coverage_path_len : 42136
#             coverage : 1.0
#           redundancy : 0.262123708252209
#           area_shape : (256, 256)
#
# # 3 ::  (144, 256) comb_8.png
# CPU times: user 37.6 s, sys: 159 ms, total: 37.7 s
# Wall time: 38.8 s
#      points_to_visit : 24720
#      obstacle_points : 12144
#       points_visited : 24720
#    coverage_path_len : 26758
#             coverage : 1.0
#           redundancy : 0.0824433656957928
#           area_shape : (144, 256)
#
# # 4 ::  (32, 32) pipes_0.png
# CPU times: user 208 ms, sys: 2.07 ms, total: 210 ms
# Wall time: 212 ms
#      points_to_visit : 689
#      obstacle_points : 335
#       points_visited : 689
#    coverage_path_len : 817
#             coverage : 1.0
#           redundancy : 0.18577648766328014
#           area_shape : (32, 32)
#
# # 5 ::  (32, 32) pipes_1.png
# CPU times: user 372 ms, sys: 3.84 ms, total: 376 ms
# Wall time: 384 ms
#      points_to_visit : 639
#      obstacle_points : 385
#       points_visited : 639
#    coverage_path_len : 922
#             coverage : 1.0
#           redundancy : 0.44287949921752734
#           area_shape : (32, 32)
#
# # 6 ::  (32, 32) pipes_2.png
# CPU times: user 454 ms, sys: 3.59 ms, total: 458 ms
# Wall time: 464 ms
#      points_to_visit : 654
#      obstacle_points : 370
#       points_visited : 654
#    coverage_path_len : 909
#             coverage : 1.0
#           redundancy : 0.38990825688073394
#           area_shape : (32, 32)
#
# # 7 ::  (32, 32) caves_1.png
# CPU times: user 246 ms, sys: 2.91 ms, total: 249 ms
# Wall time: 258 ms
#      points_to_visit : 794
#      obstacle_points : 230
#       points_visited : 794
#    coverage_path_len : 942
#             coverage : 1.0
#           redundancy : 0.18639798488664994
#           area_shape : (32, 32)
#
# # 8 ::  (32, 32) caves_0.png
# CPU times: user 216 ms, sys: 1.45 ms, total: 217 ms
# Wall time: 218 ms
#      points_to_visit : 725
#      obstacle_points : 299
#       points_visited : 725
#    coverage_path_len : 885
#             coverage : 1.0
#           redundancy : 0.2206896551724138
#           area_shape : (32, 32)
#
# # 9 ::  (32, 32) center_0.png
# CPU times: user 343 ms, sys: 2.3 ms, total: 345 ms
# Wall time: 359 ms
#      points_to_visit : 723
#      obstacle_points : 301
#       points_visited : 723
#    coverage_path_len : 900
#             coverage : 1.0
#           redundancy : 0.24481327800829877
#           area_shape : (32, 32)
#
# # 10 ::  (144, 256) center_1.png
# CPU times: user 17 s, sys: 50 ms, total: 17 s
# Wall time: 17.2 s
#      points_to_visit : 36713
#      obstacle_points : 151
#       points_visited : 36713
#    coverage_path_len : 37476
#             coverage : 1.0
#           redundancy : 0.020782828970664413
#           area_shape : (144, 256)
#
# # 11 ::  (50, 144) comb_5.png
# CPU times: user 1.53 s, sys: 5.13 ms, total: 1.53 s
# Wall time: 1.55 s
#      points_to_visit : 4383
#      obstacle_points : 2817
#       points_visited : 4383
#    coverage_path_len : 4608
#             coverage : 1.0
#           redundancy : 0.05133470225872694
#           area_shape : (50, 144)
#
# # 12 ::  (50, 144) comb_4.png
# CPU times: user 2.84 s, sys: 10.1 ms, total: 2.85 s
# Wall time: 2.88 s
#      points_to_visit : 4161
#      obstacle_points : 3039
#       points_visited : 4095
#    coverage_path_len : 4752
#             coverage : 0.9841384282624369
#           redundancy : 0.16043956043956054
#           area_shape : (50, 144)
#
# # 13 ::  (50, 144) comb_6.png
# CPU times: user 2.34 s, sys: 7.27 ms, total: 2.35 s
# Wall time: 2.37 s
#      points_to_visit : 6042
#      obstacle_points : 1158
#       points_visited : 6042
#    coverage_path_len : 6794
#             coverage : 1.0
#           redundancy : 0.12446209864283353
#           area_shape : (50, 144)
#
# # 14 ::  (144, 256) comb_7.png
# CPU times: user 1min 40s, sys: 296 ms, total: 1min 40s
# Wall time: 1min 41s
#      points_to_visit : 25866
#      obstacle_points : 10998
#       points_visited : 25866
#    coverage_path_len : 30943
#             coverage : 1.0
#           redundancy : 0.19628083198020563
#           area_shape : (144, 256)
#
# # 15 ::  (50, 144) comb_3.png
# CPU times: user 7.38 s, sys: 21.6 ms, total: 7.4 s
# Wall time: 7.46 s
#      points_to_visit : 3680
#      obstacle_points : 3520
#       points_visited : 3680
#    coverage_path_len : 4787
#             coverage : 1.0
#           redundancy : 0.30081521739130435
#           area_shape : (50, 144)
#
# # 16 ::  (32, 32) comb_11.png
# CPU times: user 200 ms, sys: 1.89 ms, total: 201 ms
# Wall time: 203 ms
#      points_to_visit : 772
#      obstacle_points : 252
#       points_visited : 415
#    coverage_path_len : 570
#             coverage : 0.5375647668393783
#           redundancy : 0.37349397590361444
#           area_shape : (32, 32)
#
# # 17 ::  (50, 50) comb_2.png
# CPU times: user 1.46 s, sys: 5.81 ms, total: 1.47 s
# Wall time: 1.49 s
#      points_to_visit : 1318
#      obstacle_points : 1182
#       points_visited : 1318
#    coverage_path_len : 1842
#             coverage : 1.0
#           redundancy : 0.3975720789074355
#           area_shape : (50, 50)
#
# # 18 ::  (50, 50) comb_0.png
# CPU times: user 1.03 s, sys: 4.15 ms, total: 1.04 s
# Wall time: 1.04 s
#      points_to_visit : 1529
#      obstacle_points : 971
#       points_visited : 1529
#    coverage_path_len : 1798
#             coverage : 1.0
#           redundancy : 0.17593198168737745
#           area_shape : (50, 50)
#
# # 19 ::  (32, 32) comb_12.png
# CPU times: user 163 ms, sys: 1.74 ms, total: 165 ms
# Wall time: 165 ms
#      points_to_visit : 610
#      obstacle_points : 414
#       points_visited : 246
#    coverage_path_len : 406
#             coverage : 0.40327868852459015
#           redundancy : 0.6504065040650406
#           area_shape : (32, 32)
#
# # 20 ::  (50, 50) comb_1.png
# CPU times: user 1.01 s, sys: 5.09 ms, total: 1.02 s
# Wall time: 1.03 s
#      points_to_visit : 1472
#      obstacle_points : 1028
#       points_visited : 1472
#    coverage_path_len : 1845
#             coverage : 1.0
#           redundancy : 0.2533967391304348
#           area_shape : (50, 50)
